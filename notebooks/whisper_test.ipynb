# %%
import numpy as np
import torch
import pandas as pd
import whisper

pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 1000
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model = whisper.load_model("tiny.en", download_root="D:/models/whisper/")
print(
    f"Model is {'multilingual' if model.is_multilingual else 'English-only'} "
    f"and has {sum(np.prod(p.shape) for p in model.parameters()):,} parameters."
)
# Out:
# Model is English-only and has 37,184,256 parameters.

# %%
path = "D:/dataset/librivox/downloads/14_353_11.mp3"
result = model.transcribe(path)
print(result["text"])
# Out:
#  This is a Librovax recording. Our Librovax recordings are in the public domain. For more information or to volunteer, please visit Librovax.org. Recording by Kristin Luoma, greenkri.com. A-Subs fables. The wolf and the lamb. A wolf came upon the lamb, straying from the flock, and felt some compunction about taking the life of so helpless a creature without some plausible excuse. So he cast about four grievance and said at last, last year, Sarah, you grossly insulted me. That is impossible, sir, leaded the lamb, for I wasn't born then. Well, retorted the wolf, you feed in my pastures. That cannot be, replied the lamb, for I have never yet tasted grass. You drink from my spring then, continued the wolf. Indeed, sir, said the poor lamb. I have never yet drunk anything but my mother's milk. Well, anyhow, said the wolf. I'm not going without my dinner, and he sprang upon the lamb and devoured it without more ado. End of the wolf and the lamb.

# %%
from IPython.display import Audio

# 读取MP3文件
with open(path, "rb") as f:
    mp3_data = f.read()

# 在Jupyter Notebook中显示MP3
Audio(mp3_data, autoplay=True, rate=16000)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for seg in result["segments"]:
    print(seg["no_speech_prob"])
# Out:
# 0.2084711641073227
# 0.2084711641073227
# 0.2084711641073227
# 0.2084711641073227
# 0.2084711641073227
# 0.2084711641073227
# 0.012944634072482586
# 0.012944634072482586
# 0.012944634072482586
# 0.012944634072482586
# 0.012944634072482586
# 0.012944634072482586
# 0.012944634072482586
# 0.012944634072482586
# 0.24414044618606567
# 0.24414044618606567
# 0.24414044618606567
# 0.24414044618606567
# 0.24414044618606567
# 0.24414044618606567
# 0.24414044618606567
# 0.24414044618606567
# 0.14055615663528442

# %%
result
# Out:
# {'text': " This is a Librovax recording. Our Librovax recordings are in the public domain. For more information or to volunteer, please visit Librovax.org. Recording by Kristin Luoma, greenkri.com. A-Subs fables. The wolf and the lamb. A wolf came upon the lamb, straying from the flock, and felt some compunction about taking the life of so helpless a creature without some plausible excuse. So he cast about four grievance and said at last, last year, Sarah, you grossly insulted me. That is impossible, sir, leaded the lamb, for I wasn't born then. Well, retorted the wolf, you feed in my pastures. That cannot be, replied the lamb, for I have never yet tasted grass. You drink from my spring then, continued the wolf. Indeed, sir, said the poor lamb. I have never yet drunk anything but my mother's milk. Well, anyhow, said the wolf. I'm not going without my dinner, and he sprang upon the lamb and devoured it without more ado. End of the wolf and the lamb.",
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 4.68,
#    'text': ' This is a Librovax recording.',
#    'tokens': [50363, 770, 318, 257, 7980, 18657, 897, 8296, 13, 50597],
#    'temperature': 0.0,
#    'avg_logprob': -0.58218172434214,
#    'compression_ratio': 1.4177215189873418,
#    'no_speech_prob': 0.2084711641073227},
#   {'id': 1,
#    'seek': 0,
#    'start': 4.68,
#    'end': 8.24,
#    'text': ' Our Librovax recordings are in the public domain.',
#    'tokens': [50597,
#     3954,
#     7980,
#     18657,
#     897,
#     18813,
#     389,
#     287,
#     262,
#     1171,
#     7386,
#     13,
#     50775],
#    'temperature': 0.0,
#    'avg_logprob': -0.58218172434214,
#    'compression_ratio': 1.4177215189873418,
#    'no_speech_prob': 0.2084711641073227},
#   {'id': 2,
#    'seek': 0,
#    'start': 8.24,
#    'end': 15.120000000000001,
#    'text': ' For more information or to volunteer, please visit Librovax.org.',
#    'tokens': [50775,
#     1114,
#     517,
#     1321,
#     393,
#     284,
#     13904,
#     11,
#     3387,
#     3187,
#     7980,
#     18657,
#     897,
#     13,
#     2398,
#     13,
#     51119],
#    'temperature': 0.0,
#    'avg_logprob': -0.58218172434214,
#    'compression_ratio': 1.4177215189873418,
#    'no_speech_prob': 0.2084711641073227},
#   {'id': 3,
#    'seek': 0,
#    'start': 15.120000000000001,
#    'end': 22.2,
#    'text': ' Recording by Kristin Luoma, greenkri.com.',
#    'tokens': [51119,
#     43905,
#     416,
#     14912,
#     259,
#     6026,
#     6086,
#     11,
#     4077,
#     74,
#     380,
#     13,
#     785,
#     13,
#     51473],
#    'temperature': 0.0,
#    'avg_logprob': -0.58218172434214,
#    'compression_ratio': 1.4177215189873418,
#    'no_speech_prob': 0.2084711641073227},
#   {'id': 4,
#    'seek': 0,
#    'start': 22.2,
#    'end': 24.84,
#    'text': ' A-Subs fables.',
#    'tokens': [51473, 317, 12, 7004, 82, 277, 2977, 13, 51605],
#    'temperature': 0.0,
#    'avg_logprob': -0.58218172434214,
#    'compression_ratio': 1.4177215189873418,
#    'no_speech_prob': 0.2084711641073227},
#   {'id': 5,
#    'seek': 0,
#    'start': 24.84,
#    'end': 29.0,
#    'text': ' The wolf and the lamb.',
#    'tokens': [51605, 383, 17481, 290, 262, 19343, 13, 51813],
#    'temperature': 0.0,
#    'avg_logprob': -0.58218172434214,
#    'compression_ratio': 1.4177215189873418,
#    'no_speech_prob': 0.2084711641073227},
#   {'id': 6,
#    'seek': 2900,
#    'start': 30.0,
#    'end': 33.36,
#    'text': ' A wolf came upon the lamb, straying from the flock,',
#    'tokens': [50413,
#     317,
#     17481,
#     1625,
#     2402,
#     262,
#     19343,
#     11,
#     965,
#     8369,
#     422,
#     262,
#     29556,
#     11,
#     50581],
#    'temperature': 0.0,
#    'avg_logprob': -0.3354916572570801,
#    'compression_ratio': 1.553191489361702,
#    'no_speech_prob': 0.012944634072482586},
#   {'id': 7,
#    'seek': 2900,
#    'start': 33.36,
#    'end': 37.4,
#    'text': ' and felt some compunction about taking the life of so helpless a creature',
#    'tokens': [50581,
#     290,
#     2936,
#     617,
#     552,
#     4575,
#     546,
#     2263,
#     262,
#     1204,
#     286,
#     523,
#     21144,
#     257,
#     7185,
#     50783],
#    'temperature': 0.0,
#    'avg_logprob': -0.3354916572570801,
#    'compression_ratio': 1.553191489361702,
#    'no_speech_prob': 0.012944634072482586},
#   {'id': 8,
#    'seek': 2900,
#    'start': 37.4,
#    'end': 39.8,
#    'text': ' without some plausible excuse.',
#    'tokens': [50783, 1231, 617, 19756, 12226, 13, 50903],
#    'temperature': 0.0,
#    'avg_logprob': -0.3354916572570801,
#    'compression_ratio': 1.553191489361702,
#    'no_speech_prob': 0.012944634072482586},
#   {'id': 9,
#    'seek': 2900,
#    'start': 39.8,
#    'end': 42.96,
#    'text': ' So he cast about four grievance and said at last,',
#    'tokens': [50903,
#     1406,
#     339,
#     3350,
#     546,
#     1440,
#     47645,
#     290,
#     531,
#     379,
#     938,
#     11,
#     51061],
#    'temperature': 0.0,
#    'avg_logprob': -0.3354916572570801,
#    'compression_ratio': 1.553191489361702,
#    'no_speech_prob': 0.012944634072482586},
#   {'id': 10,
#    'seek': 2900,
#    'start': 42.96,
#    'end': 47.0,
#    'text': ' last year, Sarah, you grossly insulted me.',
#    'tokens': [51061,
#     938,
#     614,
#     11,
#     6866,
#     993,
#     11,
#     345,
#     40316,
#     40102,
#     502,
#     13,
#     51263],
#    'temperature': 0.0,
#    'avg_logprob': -0.3354916572570801,
#    'compression_ratio': 1.553191489361702,
#    'no_speech_prob': 0.012944634072482586},
#   {'id': 11,
#    'seek': 2900,
#    'start': 47.0,
#    'end': 49.68,
#    'text': ' That is impossible, sir, leaded the lamb,',
#    'tokens': [51263,
#     1320,
#     318,
#     5340,
#     11,
#     15967,
#     11,
#     443,
#     5286,
#     262,
#     19343,
#     11,
#     51397],
#    'temperature': 0.0,
#    'avg_logprob': -0.3354916572570801,
#    'compression_ratio': 1.553191489361702,
#    'no_speech_prob': 0.012944634072482586},
#   {'id': 12,
#    'seek': 2900,
#    'start': 49.68,
#    'end': 51.8,
#    'text': " for I wasn't born then.",
#    'tokens': [51397, 329, 314, 2492, 470, 4642, 788, 13, 51503],
#    'temperature': 0.0,
#    'avg_logprob': -0.3354916572570801,
#    'compression_ratio': 1.553191489361702,
#    'no_speech_prob': 0.012944634072482586},
#   {'id': 13,
#    'seek': 2900,
#    'start': 51.8,
#    'end': 56.400000000000006,
#    'text': ' Well, retorted the wolf, you feed in my pastures.',
#    'tokens': [51503,
#     3894,
#     11,
#     1005,
#     9741,
#     262,
#     17481,
#     11,
#     345,
#     3745,
#     287,
#     616,
#     1613,
#     942,
#     13,
#     51733],
#    'temperature': 0.0,
#    'avg_logprob': -0.3354916572570801,
#    'compression_ratio': 1.553191489361702,
#    'no_speech_prob': 0.012944634072482586},
#   {'id': 14,
#    'seek': 5640,
#    'start': 56.4,
#    'end': 59.44,
#    'text': ' That cannot be, replied the lamb,',
#    'tokens': [50363, 1320, 2314, 307, 11, 8712, 262, 19343, 11, 50515],
#    'temperature': 0.0,
#    'avg_logprob': -0.21168126764985704,
#    'compression_ratio': 1.625615763546798,
#    'no_speech_prob': 0.24414044618606567},
#   {'id': 15,
#    'seek': 5640,
#    'start': 59.44,
#    'end': 62.72,
#    'text': ' for I have never yet tasted grass.',
#    'tokens': [50515, 329, 314, 423, 1239, 1865, 29187, 8701, 13, 50679],
#    'temperature': 0.0,
#    'avg_logprob': -0.21168126764985704,
#    'compression_ratio': 1.625615763546798,
#    'no_speech_prob': 0.24414044618606567},
#   {'id': 16,
#    'seek': 5640,
#    'start': 62.72,
#    'end': 66.64,
#    'text': ' You drink from my spring then, continued the wolf.',
#    'tokens': [50679,
#     921,
#     4144,
#     422,
#     616,
#     6076,
#     788,
#     11,
#     3767,
#     262,
#     17481,
#     13,
#     50875],
#    'temperature': 0.0,
#    'avg_logprob': -0.21168126764985704,
#    'compression_ratio': 1.625615763546798,
#    'no_speech_prob': 0.24414044618606567},
#   {'id': 17,
#    'seek': 5640,
#    'start': 66.64,
#    'end': 69.44,
#    'text': ' Indeed, sir, said the poor lamb.',
#    'tokens': [50875, 9676, 11, 15967, 11, 531, 262, 3595, 19343, 13, 51015],
#    'temperature': 0.0,
#    'avg_logprob': -0.21168126764985704,
#    'compression_ratio': 1.625615763546798,
#    'no_speech_prob': 0.24414044618606567},
#   {'id': 18,
#    'seek': 5640,
#    'start': 69.44,
#    'end': 73.0,
#    'text': " I have never yet drunk anything but my mother's milk.",
#    'tokens': [51015,
#     314,
#     423,
#     1239,
#     1865,
#     10785,
#     1997,
#     475,
#     616,
#     2802,
#     338,
#     7545,
#     13,
#     51193],
#    'temperature': 0.0,
#    'avg_logprob': -0.21168126764985704,
#    'compression_ratio': 1.625615763546798,
#    'no_speech_prob': 0.24414044618606567},
#   {'id': 19,
#    'seek': 5640,
#    'start': 73.0,
#    'end': 75.56,
#    'text': ' Well, anyhow, said the wolf.',
#    'tokens': [51193, 3894, 11, 597, 4919, 11, 531, 262, 17481, 13, 51321],
#    'temperature': 0.0,
#    'avg_logprob': -0.21168126764985704,
#    'compression_ratio': 1.625615763546798,
#    'no_speech_prob': 0.24414044618606567},
#   {'id': 20,
#    'seek': 5640,
#    'start': 75.56,
#    'end': 77.6,
#    'text': " I'm not going without my dinner,",
#    'tokens': [51321, 314, 1101, 407, 1016, 1231, 616, 8073, 11, 51423],
#    'temperature': 0.0,
#    'avg_logprob': -0.21168126764985704,
#    'compression_ratio': 1.625615763546798,
#    'no_speech_prob': 0.24414044618606567},
#   {'id': 21,
#    'seek': 5640,
#    'start': 77.6,
#    'end': 83.36,
#    'text': ' and he sprang upon the lamb and devoured it without more ado.',
#    'tokens': [51423,
#     290,
#     339,
#     43908,
#     2402,
#     262,
#     19343,
#     290,
#     1614,
#     8167,
#     340,
#     1231,
#     517,
#     50129,
#     13,
#     51711],
#    'temperature': 0.0,
#    'avg_logprob': -0.21168126764985704,
#    'compression_ratio': 1.625615763546798,
#    'no_speech_prob': 0.24414044618606567},
#   {'id': 22,
#    'seek': 8336,
#    'start': 83.36,
#    'end': 86.36,
#    'text': ' End of the wolf and the lamb.',
#    'tokens': [50373, 5268, 286, 262, 17481, 290, 262, 19343, 13, 50513],
#    'temperature': 0.0,
#    'avg_logprob': -0.5246833020990546,
#    'compression_ratio': 0.8787878787878788,
#    'no_speech_prob': 0.14055615663528442}],
#  'language': 'en'}
